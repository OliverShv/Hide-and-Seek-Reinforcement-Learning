# %%
import tensorflow as tf
from keras import Sequential
from keras.layers import Dense
from tensorflow.keras.models import clone_model
from collections import deque
import json

import environment
from importlib import reload
reload(environment)
import random
import numpy as np
import time

# %%
env = environment.Environment()

# %%
# Environment settings
EPISODES = 1_200
ACTION_SPACE_SIZE = 4
# Exploration settings
epsilon = 1  # not a constant, going to be decayed
MIN_EPSILON = 0.001
EPSILON_DECAY = ((epsilon - MIN_EPSILON) / EPISODES)*2
#
MAX_STEP = 50

# %%
class DQNAgent:
    def __init__(self, name):
        self.name = name
        self.DISCOUNT = 0.2
        self.REPLAY_MEMORY_SIZE = 5_000  # How many last steps to keep for model training
        self.MIN_REPLAY_MEMORY_SIZE = 1_000  # Minimum number of steps in a memory to start training
        self.MINIBATCH_SIZE = 64  # How many steps (samples) to use for training
        self.UPDATE_TARGET_EVERY = 5  # Terminal states (end of episodes)
        
        self.target_update_counter = 0
    
        self.model = Sequential(
            [
                Dense(32, activation="relu",input_shape=(4,)),
                Dense(32, activation="relu"),
                Dense(4, activation="relu"),
            ]
        )
        
        self.model.compile(loss="mse", optimizer="adam", metrics=['accuracy'])

        self.target_model = clone_model(self.model)
        self.target_model.set_weights(self.model.get_weights())
        
        self.replay_memory = deque(maxlen=self.REPLAY_MEMORY_SIZE)
        
    def train(self, terminal_state):
        if self.MIN_REPLAY_MEMORY_SIZE > len(self.replay_memory):
            return
        
        minibatch = random.sample(self.replay_memory, self.MINIBATCH_SIZE)

        current_states = tf.constant([transition[0] for transition in minibatch])
        current_qs_list = self.model.predict(current_states)
        
        new_current_states = tf.constant([transition[3] for transition in minibatch])
        future_qs_list = self.target_model.predict(new_current_states)
        
        X = []
        y = []
        
        # Now we need to enumerate our batches
        for index, (current_state, action, reward, new_current_state, done) in enumerate(minibatch):

            # If not a terminal state, get new q from future states, otherwise set it to 0
            # almost like with Q Learning, but we use just part of equation here
            if not done:
                max_future_q = np.max(future_qs_list[index])
                new_q = reward + self.DISCOUNT * max_future_q
            else:
                new_q = reward

            # Update Q value for given state
            current_qs = current_qs_list[index]
            current_qs[action] = new_q

            # And append to our training data
            X.append(current_state)
            y.append(current_qs)

        # Fit on all samples as one batch, log only on terminal state
        self.model.fit(np.array(X), np.array(y), batch_size=self.MINIBATCH_SIZE, verbose=0, shuffle=False)

        # Update target network counter every episode
        if terminal_state:
            self.target_update_counter += 1

        # If counter reaches set value, update target network with weights of main network
        if self.target_update_counter > self.UPDATE_TARGET_EVERY:
            self.target_model.set_weights(self.model.get_weights())
            self.target_update_counter = 0
    
    def get_qs(self, state):
        state = np.array(state)
        return self.model.predict(state.reshape(-1, *state.shape))[0]
    
    def update_replay_memory(self, transition):
        self.replay_memory.append(transition)
        
    def update_target_model():
        self.target_model.set_weights(self.model.get_weights())
        
    def predict(self, action):
        return self.target_model.predict(action)
    
    def save_weights(self):
        file_name = self.name+".h5"
        self.model.save_weights(file_name)
        
    def load_weights(self,filename):
        self.model.load_weights(filename)
        self.target_model.load_weights(filename)

# %%
seeker = DQNAgent("seeker")
hider = DQNAgent("hider")

agents = [hider, seeker]

# %%
# Iterate over episodes
t = time.time()

all_rewards = [[],[]]

for episode in range(1, EPISODES + 1):
    rewards = [0,0]
    print(episode, time.time()-t)
    if episode%25 == 0:
        print(episode, time.time()-t)
    step = 1

    # Reset environment and get initial state
    current_state = env.reset()

    # Reset flag and start iterating until episode ends
    done = False
    while not done:
        
        for player, agent in enumerate(agents):
            # This part stays mostly the same, the change is to query a model for Q values
            if np.random.random() > epsilon:
                # Get action from Q table
                action = np.argmax(agent.get_qs(current_state))
            else:
                # Get random action
                action = np.random.randint(0, ACTION_SPACE_SIZE)
            
            new_state, reward, done = env.step(action, player)
            rewards[player] += reward
            # Every step we update replay memory and train main network
            agent.update_replay_memory((current_state, action, reward, new_state, done))
            #On-policy learning
            agent.train(done)
            
            current_state = new_state
            step += 1
            
            if step >= MAX_STEP:
                done = True
                break
    
    all_rewards[0].append(rewards[0])
    all_rewards[1].append(rewards[1])
    # Decay epsilon
    if epsilon > MIN_EPSILON:
        epsilon -= EPSILON_DECAY
        epsilon = max(MIN_EPSILON, epsilon)

hider.save_weights()
seeker.save_weights()

with open("rewards.json", 'w') as file:
    json.dump(all_rewards, file)
# Out:
# 1 0.0
# 2 0.11700153350830078
# 3 0.22800135612487793
# 4 0.254042387008667
# 5 0.30500125885009766
# 6 0.4850022792816162
# 7 0.6100025177001953
# 8 0.8470010757446289
# 9 0.9460012912750244
# 10 1.153001308441162
# 11 1.307002067565918
# 12 1.3580012321472168
# 13 1.4400010108947754
# 14 1.5410010814666748
# 15 1.6460003852844238
# 16 1.7990012168884277
# 17 1.8280010223388672
# 18 1.9530012607574463
# 19 2.0040013790130615
# 20 2.1070010662078857
# 21 2.311000347137451
# 22 2.5180015563964844
# 23 2.6240007877349854
# 24 2.649000644683838
# 25 2.8560009002685547
# 25 2.8560009002685547
# 26 3.009000778198242
# 27 3.1150007247924805
# 28 3.344000816345215
# 29 3.4690020084381104
# 30 3.7510013580322266
# 31 4.005000829696655
# 32 4.080000638961792
# 33 4.336000680923462
# 34 4.489001989364624
# 35 4.489001989364624
# 36 4.566000461578369
# 37 4.848001003265381
# 38 4.974000930786133
# 39 5.129029989242554
# 40 5.309001445770264
# 41 5.440001010894775
# 42 5.590002536773682
# ...

# %%
import matplotlib.pyplot as plt

# %%
with open("rewards.json", 'r') as file:
    loaded_list = json.load(file)

plt.title("Seeker vs Hider total rewards for each episode")
plt.plot(loaded_list[0])
plt.plot(loaded_list[1])

# %%
env = environment.Environment(True)

seeker = DQNAgent("seeker")
seeker.load_weights("seeker.h5")
hider = DQNAgent("hider")
hider.load_weights("hider.h5")
agents = [hider, seeker]
# Reset environment and get initial state
current_state = env.reset()

# Reset flag and start iterating until episode ends
done = False

# Hider starts
step = 0
while not done:
    
    for player, agent in enumerate(agents):
        action = np.argmax(agent.get_qs(current_state))
        new_state, reward, done = env.step(action, player)
        current_state = new_state
        step += 1

        if step >= 50:
            done = True
            break
env.quit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
